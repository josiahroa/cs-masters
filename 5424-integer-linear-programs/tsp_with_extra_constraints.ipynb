# %%
from pulp import *

# %%
from pulp import LpProblem, LpVariable, LpMinimize, lpSum, LpStatus

def tsp_with_extra_constraints(n, cost_matrix, constraints):
    assert len(cost_matrix) == n, f'Cost matrix is not {n}x{n}'
    assert all(len(cj) == n for cj in cost_matrix), f'Cost matrix is not {n}x{n}'
    assert all( 1 <= i < n and 1 <= j < n and i != j for (i,j) in constraints)
    
    prob = LpProblem("TSP_with_constraints", LpMinimize)
    
    # Create binary variables for edges
    x = {}
    for i in range(n):
        for j in range(n):
            if i != j:
                x[(i, j)] = LpVariable(f"edge_{i}_{j}", cat='Binary')
    
            
    # Create variables for vertex positions in tour (u[i] represents position of vertex i)
    u = {}
    for i in range(1, n):
        u[i] = LpVariable(f"pos_{i}", lowBound=1, upBound=n-1, cat='Integer')
    
    # Objective function: minimize total cost
    prob += lpSum(cost_matrix[i][j] * x[i,j]
                 for i in range(n)
                 for j in range(n)
                 if i != j)
    
    # Constraint: each vertex must be entered exactly once
    for j in range(n):
        prob += lpSum(x[i,j] for i in range(n) if i != j) == 1
    
    # Constraint: each vertex must be exited exactly once
    for i in range(n):
        prob += lpSum(x[i,j] for j in range(n) if i != j) == 1
    
    # Subtour elimination constraints (MTZ formulation)
    for i in range(1, n):
        for j in range(1, n):
            if i != j:
                prob += u[i] - u[j] + n * x[i,j] <= n - 1
    
    # Add precedence constraints
    for (i, j) in constraints:
        if i != 0 and j != 0:  # Skip if either vertex is the start/end point
            prob += u[i] <= u[j] - 1
    
    # Solve the problem
    prob.solve()
    
    # Extract the tour
    tour = [0]  # Start at vertex 0
    current = 0
    for _ in range(n-1):
        for j in range(n):
            if j != current and value(x[current,j]) > 0.5:
                tour.append(j)
                current = j
                break
                
    return tour

# %%
cost_matrix=[ [None,3,4,3,5],
             [1, None, 2,4, 1],
             [2, 1, None, 5, 4],
             [1, 1, 5, None, 4],
             [2, 1, 3, 5, None] ]
n=5
constraints = [(3,4),(1,2)]
tour = tsp_with_extra_constraints(n, cost_matrix, constraints)
i = 0
tour_cost = 0
for j in tour[1:]:
    tour_cost += cost_matrix[i][j]
    i = j
tour_cost += cost_matrix[i][0]
print(f'Tour:{tour}')
print(f'Cost of your tour: {tour_cost}')
assert abs(tour_cost-10) <= 0.001, 'Expected cost was 10'
for i in range(n):
    num = sum([1 if j == i else 0 for j in tour])
    assert  num == 1, f'Vertex {i} repeats {num} times in tour'
for (i, j) in constraints:
    assert tour.index(i) < tour.index(j), f'Tour does not respect constraint {(i,j)}'
print('Test Passed (3 points)')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/josiahroa/workspace/cs-masters/5414-greedy-algorithms/karatsuba/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/240bbf6760f94421a03e4b79afbb70d1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/240bbf6760f94421a03e4b79afbb70d1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 29 COLUMNS
# At line 178 RHS
# At line 203 BOUNDS
# At line 232 ENDATA
# Problem MODEL has 24 rows, 24 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 9.5 - 0.00 seconds
# Cgl0003I 2 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 0 tightened bounds, 8 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 22 rows, 21 columns (21 integer (17 of which binary)) and 104 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 1.55431e-15
# Cbc0038I Solution found of 10
# Cbc0038I Cleaned solution of 10
# Cbc0038I Before mini branch and bound, 21 integers at bound fixed and 0 continuous of which 2 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 10 - took 0.00 seconds
# Cbc0012I Integer solution of 10 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 10, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 10 to 10
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                10.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Tour:[0, 3, 1, 4, 2]
# Cost of your tour: 10
# Test Passed (3 points)

# %%
cost_matrix=[ [None,3,4,3,5],
             [1, None, 2,4, 1],
             [2, 1, None, 5, 4],
             [1, 1, 5, None, 4],
             [2, 1, 3, 5, None] ]
n=5
constraints = [(4,3),(1,2)]
tour = tsp_with_extra_constraints(n, cost_matrix, constraints)
i = 0
tour_cost = 0
for j in tour[1:]:
    tour_cost += cost_matrix[i][j]
    i = j
tour_cost += cost_matrix[i][0]
print(f'Tour:{tour}')
print(f'Cost of your tour: {tour_cost}')
assert abs(tour_cost-13) <= 0.001, 'Expected cost was 13'
for i in range(n):
    num = sum([1 if j == i else 0 for j in tour])
    assert  num == 1, f'Vertex {i} repeats {num} times in tour'
for (i, j) in constraints:
    assert tour.index(i) < tour.index(j), f'Tour does not respect constraint {(i,j)}'
print('Test Passed (3 points)')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/josiahroa/workspace/cs-masters/5414-greedy-algorithms/karatsuba/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/8a81d0e2e2b846d5bb48de49442f7aba-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/8a81d0e2e2b846d5bb48de49442f7aba-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 29 COLUMNS
# At line 178 RHS
# At line 203 BOUNDS
# At line 232 ENDATA
# Problem MODEL has 24 rows, 24 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 9.5 - 0.00 seconds
# Cgl0003I 2 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 23 rows, 22 columns (22 integer (18 of which binary)) and 113 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 4.10783e-15
# Cbc0038I Solution found of 13
# Cbc0038I Cleaned solution of 13
# Cbc0038I Before mini branch and bound, 22 integers at bound fixed and 0 continuous of which 2 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 13 - took 0.00 seconds
# Cbc0012I Integer solution of 13 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective 13, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 13 to 13
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                13.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Tour:[0, 1, 4, 2, 3]
# Cost of your tour: 13
# Test Passed (3 points)

# %%
from random import uniform, randint

def create_cost(n):
    return [ [uniform(0, 5) if i != j else None for j in range(n)] for i in range(n)]

for trial in range(20):
    print(f'Trial # {trial}')
    n = randint(6, 11)
    cost_matrix = create_cost(n)
    constraints = [(1, 3), (4, 2), (n-1, 1), (n-2, 2)]
    tour = tsp_with_extra_constraints(n, cost_matrix, constraints)
    i = 0
    tour_cost = 0
    for j in tour[1:]:
        tour_cost += cost_matrix[i][j]
        i = j
    tour_cost += cost_matrix[i][0]
    print(f'Tour:{tour}')
    print(f'Cost of your tour: {tour_cost}')
    for i in range(n):
        num = sum([1 if j == i else 0 for j in tour])
        assert  num == 1, f'Vertex {i} repeats {num} times in tour'
    for (i, j) in constraints:
        assert tour.index(i) < tour.index(j), f'Tour does not respect constraint {(i,j)}'
print('Test Passed (10 points)')
# Out:
# Trial # 0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/josiahroa/workspace/cs-masters/5414-greedy-algorithms/karatsuba/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/93c6f8dff9a54f55baa2d93e349787aa-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/93c6f8dff9a54f55baa2d93e349787aa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 41 COLUMNS
# At line 270 RHS
# At line 307 BOUNDS
# At line 348 ENDATA
# Problem MODEL has 36 rows, 35 columns and 128 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6.05494 - 0.00 seconds
# Cgl0003I 3 fixed, 0 tightened bounds, 19 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 16 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 16 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0004I processed model has 32 rows, 31 columns (31 integer (26 of which binary)) and 185 elements
# Cbc0038I Initial state - 11 integers unsatisfied sum - 2.88889
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 11.3805 iterations 4
# Cbc0038I Solution found of 11.3805
# Cbc0038I Cleaned solution of 11.3805
# Cbc0038I Before mini branch and bound, 20 integers at bound fixed and 0 continuous of which 2 were internal integer and 0 internal continuous
# Cbc0038I Full problem 32 rows 31 columns, reduced to 5 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from 11.3805 to 11.3805 (0.01 seconds)
# Cbc0038I Round again with cutoff of 11.2544
# Cbc0038I Reduced cost fixing fixed 7 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.32631 (10) obj. 11.2544 iterations 4
# Cbc0038I Pass   3: suminf.    0.32631 (10) obj. 11.2544 iterations 1
# Cbc0038I Pass   4: suminf.    0.46011 (10) obj. 11.2544 iterations 6
# Cbc0038I Pass   5: suminf.    0.21030 (9) obj. 11.2544 iterations 2
# Cbc0038I Pass   6: suminf.    0.30268 (7) obj. 11.2544 iterations 5
# Cbc0038I Pass   7: suminf.    0.30268 (7) obj. 11.2544 iterations 3
# Cbc0038I Pass   8: suminf.    0.30268 (7) obj. 11.2544 iterations 2
# Cbc0038I Pass   9: suminf.    0.30268 (7) obj. 11.2544 iterations 2
# Cbc0038I Pass  10: suminf.    2.52727 (10) obj. 11.2544 iterations 6
# Cbc0038I Pass  11: suminf.    0.32631 (10) obj. 11.2544 iterations 4
# Cbc0038I Pass  12: suminf.    0.30268 (7) obj. 11.2544 iterations 5
# Cbc0038I Pass  13: suminf.    0.30268 (7) obj. 11.2544 iterations 1
# Cbc0038I Pass  14: suminf.    0.32631 (10) obj. 11.2544 iterations 2
# Cbc0038I Pass  15: suminf.    0.49539 (14) obj. 11.2544 iterations 3
# Cbc0038I Pass  16: suminf.    3.29574 (12) obj. 11.2544 iterations 7
# Cbc0038I Pass  17: suminf.    2.84697 (10) obj. 11.2544 iterations 5
# Cbc0038I Pass  18: suminf.    0.32631 (10) obj. 11.2544 iterations 5
# Cbc0038I Pass  19: suminf.    0.46011 (10) obj. 11.2544 iterations 6
# Cbc0038I Pass  20: suminf.    0.21030 (9) obj. 11.2544 iterations 2
# Cbc0038I Pass  21: suminf.    0.30268 (7) obj. 11.2544 iterations 5
# Cbc0038I Pass  22: suminf.    0.49539 (14) obj. 11.2544 iterations 2
# Cbc0038I Pass  23: suminf.    0.32631 (10) obj. 11.2544 iterations 2
# Cbc0038I Pass  24: suminf.    0.32631 (10) obj. 11.2544 iterations 1
# Cbc0038I Pass  25: suminf.    0.80667 (10) obj. 11.2544 iterations 4
# Cbc0038I Pass  26: suminf.    0.30268 (7) obj. 11.2544 iterations 5
# Cbc0038I Pass  27: suminf.    0.32631 (10) obj. 11.2544 iterations 2
# Cbc0038I Pass  28: suminf.    0.32631 (10) obj. 11.2544 iterations 2
# Cbc0038I Pass  29: suminf.    0.32631 (10) obj. 11.2544 iterations 1
# Cbc0038I Pass  30: suminf.    0.30268 (7) obj. 11.2544 iterations 1
# Cbc0038I Pass  31: suminf.    0.30268 (7) obj. 11.2544 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 14 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 32 rows 31 columns, reduced to 7 rows 5 columns
# Cbc0038I Mini branch and bound improved solution from 11.3805 to 11.357 (0.02 seconds)
# Cbc0038I Round again with cutoff of 11.0275
# Cbc0038I Reduced cost fixing fixed 7 variables on major pass 3
# Cbc0038I Pass  31: suminf.    0.91363 (10) obj. 11.0275 iterations 0
# Cbc0038I Pass  32: suminf.    0.91363 (10) obj. 11.0275 iterations 1
# Cbc0038I Pass  33: suminf.    1.47878 (10) obj. 11.0275 iterations 6
# Cbc0038I Pass  34: suminf.    0.67591 (9) obj. 11.0275 iterations 2
# Cbc0038I Pass  35: suminf.    0.84747 (7) obj. 11.0275 iterations 5
# Cbc0038I Pass  36: suminf.    0.91363 (10) obj. 11.0275 iterations 2
# Cbc0038I Pass  37: suminf.    0.91363 (10) obj. 11.0275 iterations 0
# Cbc0038I Pass  38: suminf.    0.91363 (10) obj. 11.0275 iterations 1
# Cbc0038I Pass  39: suminf.    1.38702 (14) obj. 11.0275 iterations 3
# Cbc0038I Pass  40: suminf.    1.38702 (14) obj. 11.0275 iterations 0
# Cbc0038I Pass  41: suminf.    0.84747 (7) obj. 11.0275 iterations 3
# Cbc0038I Pass  42: suminf.    0.91363 (10) obj. 11.0275 iterations 4
# Cbc0038I Pass  43: suminf.    2.03859 (15) obj. 11.0275 iterations 4
# Cbc0038I Pass  44: suminf.    1.38702 (14) obj. 11.0275 iterations 2
# Cbc0038I Pass  45: suminf.    0.84747 (7) obj. 11.0275 iterations 4
# Cbc0038I Pass  46: suminf.    0.91363 (10) obj. 11.0275 iterations 4
# Cbc0038I Pass  47: suminf.    1.16667 (10) obj. 10.9297 iterations 3
# Cbc0038I Pass  48: suminf.    1.47878 (10) obj. 11.0275 iterations 5
# Cbc0038I Pass  49: suminf.    0.67591 (9) obj. 11.0275 iterations 3
# Cbc0038I Pass  50: suminf.    0.67591 (9) obj. 11.0275 iterations 0
# Cbc0038I Pass  51: suminf.    0.67591 (9) obj. 11.0275 iterations 1
# Cbc0038I Pass  52: suminf.    0.67591 (9) obj. 11.0275 iterations 1
# Cbc0038I Pass  53: suminf.    0.67591 (9) obj. 11.0275 iterations 3
# Cbc0038I Pass  54: suminf.    0.84747 (7) obj. 11.0275 iterations 4
# Cbc0038I Pass  55: suminf.    0.84747 (7) obj. 11.0275 iterations 1
# Cbc0038I Pass  56: suminf.    0.91363 (10) obj. 11.0275 iterations 5
# Cbc0038I Pass  57: suminf.    0.84747 (7) obj. 11.0275 iterations 1
# Cbc0038I Pass  58: suminf.    0.84747 (7) obj. 11.0275 iterations 2
# Cbc0038I Pass  59: suminf.    0.91363 (10) obj. 11.0275 iterations 2
# Cbc0038I Pass  60: suminf.    0.91363 (10) obj. 11.0275 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 14 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 32 rows 31 columns, reduced to 7 rows 5 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 11.357 - took 0.02 seconds
# Cbc0012I Integer solution of 11.356959 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0038I Full problem 32 rows 31 columns, reduced to 6 rows 5 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 10.119547 to 10.119547 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 4 column cuts (4 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 11.3569593604118, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 7 variables fixed on reduced cost
# Cuts at root node changed objective from 10.1195 to 10.1195
# Probing was tried 1 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                11.35695936
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Tour:[0, 5, 1, 4, 3, 2]
# Cost of your tour: 11.356959360411288
# Trial # 1
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/josiahroa/workspace/cs-masters/5414-greedy-algorithms/karatsuba/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/e7f656a32dbd49309060d0575dafeae9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/e7f656a32dbd49309060d0575dafeae9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 121 COLUMNS
# At line 970 RHS
# At line 1087 BOUNDS
# At line 1218 ENDATA
# Problem MODEL has 116 rows, 120 columns and 498 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 10.2912 - 0.00 seconds
# Cgl0003I 1 fixed, 0 tightened bounds, 90 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 89 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 90 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 90 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 90 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 89 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 88 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 86 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 77 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0004I processed model has 116 rows, 119 columns (119 integer (109 of which binary)) and 1290 elements
# Cbc0038I Initial state - 12 integers unsatisfied sum - 3.80597
# Cbc0038I Pass   1: suminf.    2.90444 (10) obj. 12.2419 iterations 22
# Cbc0038I Pass   2: suminf.    3.17663 (21) obj. 12.0075 iterations 11
# Cbc0038I Pass   3: suminf.    2.95000 (9) obj. 21.1911 iterations 50
# Cbc0038I Pass   4: suminf.    4.52460 (18) obj. 22.1859 iterations 19
# Cbc0038I Pass   5: suminf.    3.80342 (10) obj. 24.7972 iterations 36
# Cbc0038I Pass   6: suminf.    5.10256 (18) obj. 26.6768 iterations 17
# Cbc0038I Pass   7: suminf.    2.22667 (21) obj. 25.9645 iterations 18
# Cbc0038I Pass   8: suminf.    3.33333 (9) obj. 24.9468 iterations 37
# Cbc0038I Pass   9: suminf.    3.22807 (11) obj. 24.3623 iterations 18
# Cbc0038I Pass  10: suminf.    2.77399 (14) obj. 27.7967 iterations 42
# Cbc0038I Pass  11: suminf.    3.30500 (15) obj. 26.228 iterations 36
# Cbc0038I Pass  12: suminf.    2.42346 (11) obj. 25.9126 iterations 11
# Cbc0038I Pass  13: suminf.    3.11111 (8) obj. 25.4918 iterations 25
# Cbc0038I Pass  14: suminf.    2.86275 (15) obj. 26.9083 iterations 15
# Cbc0038I Pass  15: suminf.    2.46667 (7) obj. 25.5148 iterations 49
# Cbc0038I Pass  16: suminf.    2.46667 (7) obj. 25.5148 iterations 3
# Cbc0038I Pass  17: suminf.    2.66667 (6) obj. 24.5849 iterations 17
# Cbc0038I Pass  18: suminf.    2.39111 (13) obj. 23.0565 iterations 34
# Cbc0038I Pass  19: suminf.    3.41026 (11) obj. 25.2711 iterations 38
# Cbc0038I Pass  20: suminf.    2.00000 (6) obj. 25.0722 iterations 26
# Cbc0038I Pass  21: suminf.    2.20814 (12) obj. 22.1205 iterations 22
# Cbc0038I Pass  22: suminf.    3.11538 (9) obj. 25.0566 iterations 35
# Cbc0038I Pass  23: suminf.    4.30081 (17) obj. 21.258 iterations 38
# Cbc0038I Pass  24: suminf.    2.18129 (12) obj. 22.0263 iterations 27
# Cbc0038I Pass  25: suminf.    3.59259 (13) obj. 24.75 iterations 29
# Cbc0038I Pass  26: suminf.    2.60714 (16) obj. 26.4278 iterations 30
# Cbc0038I Pass  27: suminf.    2.44444 (10) obj. 27.8918 iterations 33
# Cbc0038I Pass  28: suminf.    2.28571 (11) obj. 26.7943 iterations 21
# Cbc0038I Pass  29: suminf.    2.72000 (10) obj. 24.5055 iterations 26
# Cbc0038I Pass  30: suminf.    4.77778 (17) obj. 25.6129 iterations 17
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 57 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 116 rows 119 columns, reduced to 107 rows 61 columns
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting - took 0.05 seconds
# Cbc0031I 4 added rows had average density of 107.5
# Cbc0013I At root node, 4 cuts changed objective from 10.351964 to 10.86613 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 174 row cuts average 2.5 elements, 0 column cuts (0 active)  in 0.027 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1044 row cuts average 107.1 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 9 row cuts average 89.2 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 44 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 183 row cuts average 62.9 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 1 row cuts average 37.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 10.86613 (0.21 seconds)
# Cbc0012I Integer solution of 12.666717 found by DiveCoefficient after 2475 iterations and 2 nodes (0.23 seconds)
# Cbc0038I Full problem 116 rows 119 columns, reduced to 64 rows 16 columns
# Cbc0016I Integer solution of 12.652341 found by strong branching after 2596 iterations and 8 nodes (0.25 seconds)
# Cbc0001I Search completed - best objective 12.65234062111499, took 3657 iterations and 34 nodes (0.32 seconds)
# Cbc0032I Strong branching done 716 times (6877 iterations), fathomed 12 nodes and fixed 13 variables
# Cbc0035I Maximum depth 7, 321 variables fixed on reduced cost
# Cuts at root node changed objective from 10.352 to 10.8661
# Probing was tried 218 times and created 740 cuts of which 0 were active after adding rounds of cuts (0.036 seconds)
# Gomory was tried 215 times and created 1152 cuts of which 0 were active after adding rounds of cuts (0.023 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 100 times and created 9 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# FlowCover was tried 100 times and created 44 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
# TwoMirCuts was tried 215 times and created 631 cuts of which 0 were active after adding rounds of cuts (0.023 seconds)
# ZeroHalf was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                12.65234062
# Enumerated nodes:               34
# Total iterations:               3657
# Time (CPU seconds):             0.31
# Time (Wallclock seconds):       0.32
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.31   (Wallclock seconds):       0.32
#
# Tour:[0, 10, 4, 7, 1, 9, 3, 8, 5, 6, 2]
# Cost of your tour: 12.652340621114984
# Trial # 2
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/josiahroa/workspace/cs-masters/5414-greedy-algorithms/karatsuba/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/6b7e24d5f0b24b8ca72bae73ea270218-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/6b7e24d5f0b24b8ca72bae73ea270218-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 53 COLUMNS
# At line 374 RHS
# At line 423 BOUNDS
# At line 478 ENDATA
# Problem MODEL has 48 rows, 48 columns and 182 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 4.61487 - 0.00 seconds
# Cgl0003I 5 fixed, 0 tightened bounds, 29 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 29 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 21 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 13 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 47 rows, 43 columns (43 integer (37 of which binary)) and 290 elements
# Cbc0038I Initial state - 18 integers unsatisfied sum - 5.24638
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 6.56957 iterations 18
# Cbc0038I Solution found of 6.56957
# Cbc0038I Cleaned solution of 6.56957
# Cbc0038I Before mini branch and bound, 25 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 47 rows 43 columns, reduced to 25 rows 7 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 6.52265
# Cbc0038I Reduced cost fixing fixed 17 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.28441 (7) obj. 6.52265 iterations 8
# Cbc0038I Pass   3: suminf.    1.44444 (7) obj. 6.23963 iterations 11
# Cbc0038I Pass   4: suminf.    1.44444 (7) obj. 6.23963 iterations 0
# Cbc0038I Pass   5: suminf.    0.28441 (7) obj. 6.52265 iterations 3
# Cbc0038I Pass   6: suminf.    0.27809 (12) obj. 6.52265 iterations 4
# Cbc0038I Pass   7: suminf.    0.28441 (7) obj. 6.52265 iterations 4
# Cbc0038I Pass   8: suminf.    0.27809 (12) obj. 6.52265 iterations 4
# Cbc0038I Pass   9: suminf.    0.28441 (7) obj. 6.52265 iterations 5
# Cbc0038I Pass  10: suminf.    2.29863 (13) obj. 6.52265 iterations 5
# Cbc0038I Pass  11: suminf.    0.28441 (7) obj. 6.52265 iterations 3
# Cbc0038I Pass  12: suminf.    0.28441 (7) obj. 6.52265 iterations 0
# Cbc0038I Pass  13: suminf.    0.28441 (7) obj. 6.52265 iterations 0
# Cbc0038I Pass  14: suminf.    0.27809 (12) obj. 6.52265 iterations 2
# Cbc0038I Pass  15: suminf.    0.28441 (7) obj. 6.52265 iterations 1
# Cbc0038I Pass  16: suminf.    0.28441 (7) obj. 6.52265 iterations 0
# Cbc0038I Pass  17: suminf.    0.28441 (7) obj. 6.52265 iterations 0
# Cbc0038I Pass  18: suminf.    1.44444 (7) obj. 6.23963 iterations 9
# Cbc0038I Pass  19: suminf.    0.28441 (7) obj. 6.52265 iterations 5
# Cbc0038I Pass  20: suminf.    1.44444 (7) obj. 6.23963 iterations 6
# Cbc0038I Pass  21: suminf.    1.44444 (7) obj. 6.23963 iterations 2
# Cbc0038I Pass  22: suminf.    1.44444 (7) obj. 6.23963 iterations 4
# Cbc0038I Pass  23: suminf.    0.28441 (7) obj. 6.52265 iterations 4
# Cbc0038I Pass  24: suminf.    0.28441 (7) obj. 6.52265 iterations 1
# Cbc0038I Pass  25: suminf.    0.28441 (7) obj. 6.52265 iterations 0
# Cbc0038I Pass  26: suminf.    0.28441 (7) obj. 6.52265 iterations 0
# Cbc0038I Pass  27: suminf.    0.24882 (13) obj. 6.52265 iterations 1
# Cbc0038I Pass  28: suminf.    0.24882 (13) obj. 6.52265 iterations 1
# Cbc0038I Pass  29: suminf.    0.28441 (7) obj. 6.52265 iterations 4
# Cbc0038I Pass  30: suminf.    0.28441 (7) obj. 6.52265 iterations 1
# Cbc0038I Pass  31: suminf.    0.28441 (7) obj. 6.52265 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 22 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 47 rows 43 columns, reduced to 25 rows 7 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 6.56957 - took 0.01 seconds
# Cbc0012I Integer solution of 6.5695707 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 47 rows 43 columns, reduced to 25 rows 7 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 6.1004693 to 6.1004693 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 6 column cuts (6 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 6.56957071504716, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 17 variables fixed on reduced cost
# Cuts at root node changed objective from 6.10047 to 6.10047
# Probing was tried 1 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.56957072
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Tour:[0, 4, 5, 6, 1, 2, 3]
# Cost of your tour: 6.569570715046786
# Trial # 3
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/josiahroa/workspace/cs-masters/5414-greedy-algorithms/karatsuba/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/efd25414be584222a2e069e1b13eb50b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/efd25414be584222a2e069e1b13eb50b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 53 COLUMNS
# At line 374 RHS
# At line 423 BOUNDS
# At line 478 ENDATA
# Problem MODEL has 48 rows, 48 columns and 182 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7.65475 - 0.00 seconds
# Cgl0003I 5 fixed, 0 tightened bounds, 29 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 28 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 11 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 6 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 47 rows, 43 columns (43 integer (37 of which binary)) and 284 elements
# Cbc0038I Initial state - 9 integers unsatisfied sum - 2.71429
# Cbc0038I Pass   1: suminf.    1.71429 (6) obj. 9.65668 iterations 7
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. 15.027 iterations 10
# Cbc0038I Solution found of 15.027
# Cbc0038I Cleaned solution of 15.027
# Cbc0038I Before mini branch and bound, 29 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 47 rows 43 columns, reduced to 19 rows 8 columns
# Cbc0038I Mini branch and bound improved solution from 15.027 to 11.1488 (0.01 seconds)
# Cbc0038I Round again with cutoff of 10.8888
# Cbc0038I Reduced cost fixing fixed 13 variables on major pass 2
# Cbc0038I Pass   3: suminf.    2.71429 (9) obj. 8.5486 iterations 8
# Cbc0038I Pass   4: suminf.    1.13714 (12) obj. 10.8888 iterations 6
# Cbc0038I Pass   5: suminf.    2.71429 (9) obj. 8.5486 iterations 6
# Cbc0038I Pass   6: suminf.    3.85714 (13) obj. 10.4617 iterations 5
# Cbc0038I Pass   7: suminf.    1.28576 (11) obj. 10.8888 iterations 7
# Cbc0038I Pass   8: suminf.    4.17781 (16) obj. 10.8888 iterations 4
# Cbc0038I Pass   9: suminf.    2.14293 (11) obj. 10.8888 iterations 6
# Cbc0038I Pass  10: suminf.    3.59732 (11) obj. 10.8888 iterations 7
# Cbc0038I Pass  11: suminf.    2.14293 (11) obj. 10.8888 iterations 7
# Cbc0038I Pass  12: suminf.    3.20096 (15) obj. 10.8888 iterations 15
# Cbc0038I Pass  13: suminf.    2.08644 (11) obj. 10.8888 iterations 9
# Cbc0038I Pass  14: suminf.    4.65414 (14) obj. 10.8888 iterations 5
# Cbc0038I Pass  15: suminf.    3.67195 (15) obj. 10.8888 iterations 6
# Cbc0038I Pass  16: suminf.    2.14293 (11) obj. 10.8888 iterations 11
# Cbc0038I Pass  17: suminf.    1.13714 (12) obj. 10.8888 iterations 2
# Cbc0038I Pass  18: suminf.    2.71429 (9) obj. 8.5486 iterations 6
# Cbc0038I Pass  19: suminf.    2.71429 (9) obj. 8.5486 iterations 0
# Cbc0038I Pass  20: suminf.    2.28571 (8) obj. 9.27469 iterations 7
# Cbc0038I Pass  21: suminf.    2.71429 (9) obj. 8.5486 iterations 7
# Cbc0038I Pass  22: suminf.    2.28571 (8) obj. 8.77804 iterations 9
# Cbc0038I Pass  23: suminf.    2.44898 (12) obj. 10.5669 iterations 5
# Cbc0038I Pass  24: suminf.    2.08644 (11) obj. 10.8888 iterations 10
# Cbc0038I Pass  25: suminf.    4.65414 (14) obj. 10.8888 iterations 5
# Cbc0038I Pass  26: suminf.    3.67195 (15) obj. 10.8888 iterations 5
# Cbc0038I Pass  27: suminf.    2.14293 (11) obj. 10.8888 iterations 11
# Cbc0038I Pass  28: suminf.    1.13714 (12) obj. 10.8888 iterations 2
# Cbc0038I Pass  29: suminf.    2.71429 (9) obj. 8.5486 iterations 6
# Cbc0038I Pass  30: suminf.    2.71429 (9) obj. 8.5486 iterations 0
# Cbc0038I Pass  31: suminf.    3.14286 (10) obj. 9.61945 iterations 2
# Cbc0038I Pass  32: suminf.    3.14286 (10) obj. 9.61945 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 15 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 47 rows 43 columns, reduced to 43 rows 24 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 11.1488 - took 0.02 seconds
# Cbc0012I Integer solution of 11.148778 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0038I Full problem 47 rows 43 columns, reduced to 15 rows 6 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 5 added rows had average density of 3.4
# Cbc0013I At root node, 5 cuts changed objective from 8.5486034 to 10.50301 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 14 row cuts average 3.0 elements, 4 column cuts (4 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 3 row cuts average 3.3 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 15 row cuts average 6.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 4 row cuts average 9.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0001I Search completed - best objective 11.1487779575884, took 15 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 18 variables fixed on reduced cost
# Cuts at root node changed objective from 8.5486 to 10.503
# Probing was tried 2 times and created 18 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 15 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                11.14877796
# Enumerated nodes:               0
# Total iterations:               15
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Tour:[0, 5, 6, 4, 1, 2, 3]
# Cost of your tour: 11.148777957588639
# Trial # 4
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/josiahroa/workspace/cs-masters/5414-greedy-algorithms/karatsuba/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/670589f3847c41c8afaa5fe772cda223-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/670589f3847c41c8afaa5fe772cda223-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 83 COLUMNS
# At line 636 RHS
# At line 715 BOUNDS
# At line 804 ENDATA
# Problem MODEL has 78 rows, 80 columns and 320 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 5.75962 - 0.00 seconds
# Cgl0003I 3 fixed, 0 tightened bounds, 56 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 53 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 55 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 53 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 45 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 43 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 77 rows, 77 columns (77 integer (69 of which binary)) and 671 elements
# Cbc0038I Initial state - 25 integers unsatisfied sum - 6.25453
# Cbc0038I Pass   1: suminf.    2.72545 (11) obj. 9.74372 iterations 19
# Cbc0038I Pass   2: suminf.    3.54559 (16) obj. 16.7112 iterations 22
# Cbc0038I Pass   3: suminf.    2.61538 (12) obj. 16.3177 iterations 18
# Cbc0038I Pass   4: suminf.    2.61538 (12) obj. 16.3177 iterations 3
# Cbc0038I Pass   5: suminf.    2.58961 (11) obj. 13.0261 iterations 22
# Cbc0038I Pass   6: suminf.    2.67857 (13) obj. 14.0196 iterations 16
# Cbc0038I Pass   7: suminf.    2.72857 (14) obj. 12.7046 iterations 11
# Cbc0038I Pass   8: suminf.    2.92857 (9) obj. 13.5963 iterations 18
# Cbc0038I Pass   9: suminf.    4.92308 (16) obj. 13.2213 iterations 9
# Cbc0038I Pass  10: suminf.    4.98684 (14) obj. 12.0707 iterations 20
# Cbc0038I Pass  11: suminf.    2.91541 (14) obj. 15.2276 iterations 10
# Cbc0038I Pass  12: suminf.    3.42620 (15) obj. 15.8435 iterations 23
# Cbc0038I Pass  13: suminf.    3.64017 (19) obj. 15.6921 iterations 8
# Cbc0038I Pass  14: suminf.    4.88136 (18) obj. 13.3955 iterations 31
# Cbc0038I Pass  15: suminf.    3.25000 (19) obj. 12.8333 iterations 11
# Cbc0038I Pass  16: suminf.    2.87857 (14) obj. 13.2939 iterations 20
# Cbc0038I Pass  17: suminf.    2.72857 (14) obj. 12.7046 iterations 5
# Cbc0038I Pass  18: suminf.    2.64286 (8) obj. 13.5963 iterations 20
# Cbc0038I Pass  19: suminf.    4.92308 (16) obj. 13.2213 iterations 11
# Cbc0038I Pass  20: suminf.    4.98684 (14) obj. 12.0707 iterations 24
# Cbc0038I Pass  21: suminf.    2.91541 (14) obj. 15.2276 iterations 10
# Cbc0038I Pass  22: suminf.    3.42620 (15) obj. 15.8435 iterations 22
# Cbc0038I Pass  23: suminf.    3.64017 (19) obj. 15.6921 iterations 9
# Cbc0038I Pass  24: suminf.    4.88136 (18) obj. 13.3955 iterations 31
# Cbc0038I Pass  25: suminf.    3.25000 (19) obj. 12.8333 iterations 15
# Cbc0038I Pass  26: suminf.    2.87857 (14) obj. 13.2939 iterations 22
# Cbc0038I Pass  27: suminf.    2.72857 (14) obj. 12.7046 iterations 5
# Cbc0038I Pass  28: suminf.    2.64286 (8) obj. 13.5963 iterations 20
# Cbc0038I Pass  29: suminf.    4.92308 (16) obj. 13.2213 iterations 10
# Cbc0038I Pass  30: suminf.    4.98684 (14) obj. 12.0707 iterations 23
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 37 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 77 rows 77 columns, reduced to 67 rows 37 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting - took 0.04 seconds
# Cbc0031I 10 added rows had average density of 50.1
# Cbc0013I At root node, 10 cuts changed objective from 7.0097538 to 8.6954754 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 181 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.024 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 601 row cuts average 69.6 elements, 0 column cuts (0 active)  in 0.013 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 2 row cuts average 20.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 34.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 9 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 190 row cuts average 40.8 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 29 row cuts average 16.1 elements, 0 column cuts (0 active)  in 0.205 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 8.6954754 (0.39 seconds)
# Cbc0004I Integer solution of 15.245165 found after 1917 iterations and 8 nodes (0.47 seconds)
# Cbc0038I Full problem 77 rows 77 columns, reduced to 63 rows 27 columns
# Cbc0016I Integer solution of 13.019082 found by strong branching after 2065 iterations and 14 nodes (0.52 seconds)
# Cbc0016I Integer solution of 12.753347 found by strong branching after 2486 iterations and 26 nodes (0.61 seconds)
# Cbc0038I Full problem 77 rows 77 columns, reduced to 49 rows 11 columns
# Cbc0016I Integer solution of 11.278292 found by strong branching after 4594 iterations and 61 nodes (0.90 seconds)
# Cbc0004I Integer solution of 11.224824 found after 4627 iterations and 62 nodes (0.91 seconds)
# Cbc0001I Search completed - best objective 11.22482432638663, took 4680 iterations and 64 nodes (0.91 seconds)
# Cbc0032I Strong branching done 990 times (9744 iterations), fathomed 7 nodes and fixed 20 variables
# Cbc0035I Maximum depth 12, 355 variables fixed on reduced cost
# Cuts at root node changed objective from 7.00975 to 8.69548
# Probing was tried 322 times and created 1454 cuts of which 0 were active after adding rounds of cuts (0.039 seconds)
# Gomory was tried 310 times and created 879 cuts of which 0 were active after adding rounds of cuts (0.024 seconds)
# Knapsack was tried 100 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 100 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# FlowCover was tried 100 times and created 9 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# TwoMirCuts was tried 310 times and created 486 cuts of which 0 were active after adding rounds of cuts (0.019 seconds)
# ZeroHalf was tried 310 times and created 121 cuts of which 0 were active after adding rounds of cuts (0.585 seconds)
# ImplicationCuts was tried 196 times and created 32 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                11.22482433
# Enumerated nodes:               64
# Total iterations:               4680
# Time (CPU seconds):             0.88
# Time (Wallclock seconds):       0.91
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.88   (Wallclock seconds):       0.92
#
# Tour:[0, 8, 6, 5, 7, 1, 3, 4, 2]
# Cost of your tour: 11.22482432638638
# Trial # 5
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/josiahroa/workspace/cs-masters/5414-greedy-algorithms/karatsuba/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/b25d2f5be7aa4f729dedfc605e2be73c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/b25d2f5be7aa4f729dedfc605e2be73c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 101 COLUMNS
# At line 794 RHS
# At line 891 BOUNDS
# At line 1000 ENDATA
# Problem MODEL has 96 rows, 99 columns and 404 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 8.69986 - 0.00 seconds
# Cgl0003I 1 fixed, 0 tightened bounds, 72 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 71 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 72 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 72 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 69 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 69 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 69 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 59 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8 strengthened rows, 0 substitutions
# Cgl0004I processed model has 96 rows, 98 columns (98 integer (89 of which binary)) and 961 elements
# Cbc0038I Initial state - 17 integers unsatisfied sum - 5.09877
# Cbc0038I Pass   1: suminf.    4.00840 (19) obj. 10.1733 iterations 18
# Cbc0038I Pass   2: suminf.    2.55556 (10) obj. 18.6362 iterations 29
# Cbc0038I Pass   3: suminf.    2.89630 (12) obj. 19.9988 iterations 25
# Cbc0038I Pass   4: suminf.    2.85714 (7) obj. 23.855 iterations 33
# Cbc0038I Pass   5: suminf.    2.75000 (7) obj. 20.5285 iterations 12
# Cbc0038I Pass   6: suminf.    3.74359 (18) obj. 20.4812 iterations 14
# Cbc0038I Pass   7: suminf.    3.14286 (16) obj. 20.3741 iterations 41
# Cbc0038I Pass   8: suminf.    2.54286 (11) obj. 21.2724 iterations 9
# Cbc0038I Pass   9: suminf.    2.85714 (7) obj. 21.3507 iterations 26
# Cbc0038I Pass  10: suminf.    2.39286 (10) obj. 22.4365 iterations 6
# Cbc0038I Pass  11: suminf.    2.39286 (10) obj. 22.4365 iterations 0
# Cbc0038I Pass  12: suminf.    3.57869 (16) obj. 18.1273 iterations 19
# Cbc0038I Pass  13: suminf.    2.86224 (16) obj. 17.6527 iterations 11
# Cbc0038I Pass  14: suminf.    2.65476 (12) obj. 18.1726 iterations 24
# Cbc0038I Pass  15: suminf.    3.77997 (16) obj. 16.4914 iterations 6
# Cbc0038I Pass  16: suminf.    2.57143 (6) obj. 16.1666 iterations 40
# Cbc0038I Pass  17: suminf.    3.80952 (10) obj. 18.4034 iterations 29
# Cbc0038I Pass  18: suminf.    4.63711 (21) obj. 18.9954 iterations 26
# Cbc0038I Pass  19: suminf.    2.55901 (11) obj. 27.0343 iterations 32
# Cbc0038I Pass  20: suminf.    2.60714 (11) obj. 27.0351 iterations 13
# Cbc0038I Pass  21: suminf.    2.36364 (8) obj. 24.2512 iterations 34
# Cbc0038I Pass  22: suminf.    4.28571 (14) obj. 24.1394 iterations 12
# Cbc0038I Pass  23: suminf.    3.00000 (6) obj. 20.9942 iterations 28
# Cbc0038I Pass  24: suminf.    2.07143 (7) obj. 21.6544 iterations 20
# Cbc0038I Pass  25: suminf.    2.75000 (7) obj. 22.4521 iterations 29
# Cbc0038I Pass  26: suminf.    2.50000 (7) obj. 20.028 iterations 9
# Cbc0038I Pass  27: suminf.    4.21659 (14) obj. 20.0774 iterations 17
# Cbc0038I Pass  28: suminf.    4.21659 (14) obj. 20.0774 iterations 6
# Cbc0038I Pass  29: suminf.    3.09426 (15) obj. 19.0834 iterations 33
# Cbc0038I Pass  30: suminf.    3.59375 (12) obj. 18.6363 iterations 19
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 38 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 96 rows 98 columns, reduced to 86 rows 56 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to 11.2764 (0.05 seconds)
# Cbc0038I Round again with cutoff of 11.0349
# Cbc0038I Reduced cost fixing fixed 21 variables on major pass 2
# Cbc0038I Pass  30: suminf.    2.77667 (17) obj. 9.43264 iterations 13
# Cbc0038I Pass  31: suminf.    3.81034 (15) obj. 11.0349 iterations 24
# Cbc0038I Pass  32: suminf.    2.61821 (11) obj. 11.0349 iterations 12
# Cbc0038I Pass  33: suminf.    5.17857 (13) obj. 9.83713 iterations 38
# Cbc0038I Pass  34: suminf.    6.37451 (28) obj. 11.0349 iterations 27
# Cbc0038I Pass  35: suminf.    3.84473 (20) obj. 11.0349 iterations 24
# Cbc0038I Pass  36: suminf.    5.21363 (20) obj. 11.0349 iterations 4
# Cbc0038I Pass  37: suminf.    5.13435 (17) obj. 11.0349 iterations 25
# Cbc0038I Pass  38: suminf.    3.55678 (17) obj. 10.8904 iterations 11
# Cbc0038I Pass  39: suminf.    5.95830 (17) obj. 11.0349 iterations 23
# Cbc0038I Pass  40: suminf.    3.47910 (18) obj. 10.4214 iterations 22
# Cbc0038I Pass  41: suminf.    2.95348 (16) obj. 11.0349 iterations 15
# Cbc0038I Pass  42: suminf.    3.89654 (22) obj. 11.0349 iterations 11
# Cbc0038I Pass  43: suminf.    6.23897 (21) obj. 11.0349 iterations 19
# Cbc0038I Pass  44: suminf.    3.49967 (20) obj. 11.0349 iterations 22
# Cbc0038I Pass  45: suminf.    5.21363 (20) obj. 11.0349 iterations 5
# Cbc0038I Pass  46: suminf.    5.13435 (17) obj. 11.0349 iterations 21
# Cbc0038I Pass  47: suminf.    3.55678 (17) obj. 10.8904 iterations 10
# Cbc0038I Pass  48: suminf.    5.95830 (17) obj. 11.0349 iterations 22
# Cbc0038I Pass  49: suminf.    3.47910 (18) obj. 10.4214 iterations 17
# Cbc0038I Pass  50: suminf.    2.95348 (16) obj. 11.0349 iterations 19
# Cbc0038I Pass  51: suminf.    3.89654 (22) obj. 11.0349 iterations 11
# Cbc0038I Pass  52: suminf.    6.23897 (21) obj. 11.0349 iterations 19
# Cbc0038I Pass  53: suminf.    3.49967 (20) obj. 11.0349 iterations 22
# Cbc0038I Pass  54: suminf.    5.21363 (20) obj. 11.0349 iterations 5
# Cbc0038I Pass  55: suminf.    5.13435 (17) obj. 11.0349 iterations 21
# Cbc0038I Pass  56: suminf.    3.55678 (17) obj. 10.8904 iterations 9
# Cbc0038I Pass  57: suminf.    5.95830 (17) obj. 11.0349 iterations 26
# Cbc0038I Pass  58: suminf.    3.47910 (18) obj. 10.4214 iterations 21
# Cbc0038I Pass  59: suminf.    2.95348 (16) obj. 11.0349 iterations 18
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 52 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 96 rows 98 columns, reduced to 90 rows 44 columns
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I After 0.06 seconds - Feasibility pump exiting with objective of 11.2764 - took 0.05 seconds
# Cbc0012I Integer solution of 11.27641 found by feasibility pump after 0 iterations and 0 nodes (0.06 seconds)
# Cbc0038I Full problem 96 rows 98 columns, reduced to 43 rows 9 columns
# Cbc0031I 5 added rows had average density of 34.6
# Cbc0013I At root node, 5 cuts changed objective from 8.8614869 to 9.6417405 in 14 passes
# Cbc0014I Cut generator 0 (Probing) - 36 row cuts average 2.3 elements, 1 column cuts (1 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 113 row cuts average 56.8 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 49.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# ...
# At line 891 BOUNDS
# At line 1000 ENDATA
# Problem MODEL has 96 rows, 99 columns and 404 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 5.11549 - 0.00 seconds
# Cgl0003I 1 fixed, 0 tightened bounds, 72 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 71 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 72 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 72 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 71 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 69 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 68 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 57 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 6 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 96 rows, 98 columns (98 integer (89 of which binary)) and 960 elements
# Cbc0038I Initial state - 17 integers unsatisfied sum - 5.5
# Cbc0038I Pass   1: suminf.    2.43531 (11) obj. 6.44485 iterations 31
# Cbc0038I Pass   2: suminf.    4.38338 (20) obj. 6.2976 iterations 14
# Cbc0038I Pass   3: suminf.    4.92978 (17) obj. 11.2758 iterations 19
# Cbc0038I Pass   4: suminf.    3.08301 (14) obj. 12.4506 iterations 19
# Cbc0038I Pass   5: suminf.    4.16234 (19) obj. 17.2585 iterations 43
# Cbc0038I Pass   6: suminf.    2.32143 (10) obj. 18.373 iterations 17
# Cbc0038I Pass   7: suminf.    5.69643 (17) obj. 18.4654 iterations 9
# Cbc0038I Pass   8: suminf.    5.14286 (17) obj. 18.0458 iterations 28
# Cbc0038I Pass   9: suminf.    4.09286 (25) obj. 19.2968 iterations 36
# Cbc0038I Pass  10: suminf.    3.79762 (23) obj. 19.5171 iterations 40
# Cbc0038I Pass  11: suminf.    5.10559 (15) obj. 19.1532 iterations 21
# Cbc0038I Pass  12: suminf.    5.14286 (17) obj. 18.8622 iterations 10
# Cbc0038I Pass  13: suminf.    2.85714 (11) obj. 19.3103 iterations 24
# Cbc0038I Pass  14: suminf.    3.49107 (14) obj. 18.9953 iterations 18
# Cbc0038I Pass  15: suminf.    3.45000 (17) obj. 19.5449 iterations 27
# Cbc0038I Pass  16: suminf.    3.16667 (14) obj. 20.2011 iterations 12
# Cbc0038I Pass  17: suminf.    2.91768 (14) obj. 20.5462 iterations 37
# Cbc0038I Pass  18: suminf.    2.91667 (9) obj. 20.5967 iterations 9
# Cbc0038I Pass  19: suminf.    4.40000 (18) obj. 20.0291 iterations 27
# Cbc0038I Pass  20: suminf.    4.78125 (17) obj. 20.1047 iterations 8
# Cbc0038I Pass  21: suminf.    3.06667 (10) obj. 23.3837 iterations 29
# Cbc0038I Pass  22: suminf.    5.30000 (17) obj. 24.4785 iterations 19
# Cbc0038I Pass  23: suminf.    2.73469 (8) obj. 20.5792 iterations 33
# Cbc0038I Pass  24: suminf.    2.25000 (7) obj. 19.8025 iterations 20
# Cbc0038I Pass  25: suminf.    4.13771 (18) obj. 19.9553 iterations 20
# Cbc0038I Pass  26: suminf.    4.96711 (17) obj. 20.0222 iterations 4
# Cbc0038I Pass  27: suminf.    3.33333 (10) obj. 17.9867 iterations 27
# Cbc0038I Pass  28: suminf.    3.29167 (9) obj. 18.9088 iterations 14
# Cbc0038I Pass  29: suminf.    2.65432 (9) obj. 18.8598 iterations 35
# Cbc0038I Pass  30: suminf.    2.25000 (9) obj. 18.4238 iterations 18
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 38 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 96 rows 98 columns, reduced to 89 rows 58 columns
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting - took 0.05 seconds
# Cbc0031I 9 added rows had average density of 65.444444
# Cbc0013I At root node, 9 cuts changed objective from 5.3280657 to 7.6303311 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 212 row cuts average 2.9 elements, 0 column cuts (0 active)  in 0.032 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 649 row cuts average 83.7 elements, 0 column cuts (0 active)  in 0.016 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 4 row cuts average 14.5 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 6 row cuts average 48.7 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 12 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 175 row cuts average 41.3 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 1 row cuts average 8.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 7.6303311 (0.21 seconds)
# Cbc0010I After 1000 nodes, 9 on tree, 1e+50 best solution, best possible 7.6303311 (5.68 seconds)
# Cbc0012I Integer solution of 11.072014 found by DiveCoefficient after 28691 iterations and 1006 nodes (5.70 seconds)
# Cbc0038I Full problem 96 rows 98 columns, reduced to 66 rows 21 columns
# Cbc0012I Integer solution of 10.340175 found by DiveCoefficient after 28822 iterations and 1014 nodes (5.70 seconds)
# Cbc0012I Integer solution of 9.0197643 found by DiveCoefficient after 29460 iterations and 1030 nodes (5.73 seconds)
# Cbc0001I Search completed - best objective 9.01976429719789, took 829426 iterations and 90389 nodes (5.75 seconds)
# Cbc0032I Strong branching done 9830 times (86308 iterations), fathomed 63 nodes and fixed 197 variables
# Cbc0041I Maximum depth 26, 353 variables fixed on reduced cost (complete fathoming 194 times, 89345 nodes taking 799495 iterations)
# Cuts at root node changed objective from 5.32807 to 7.63033
# Probing was tried 2550 times and created 13864 cuts of which 0 were active after adding rounds of cuts (0.185 seconds)
# Gomory was tried 2347 times and created 3349 cuts of which 0 were active after adding rounds of cuts (0.132 seconds)
# Knapsack was tried 100 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 100 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# FlowCover was tried 100 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# TwoMirCuts was tried 2347 times and created 1317 cuts of which 0 were active after adding rounds of cuts (0.102 seconds)
# ZeroHalf was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ImplicationCuts was tried 875 times and created 18 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
#
# Result - Optimal solution found
#
# Objective value:                9.01976430
# Enumerated nodes:               90389
# Total iterations:               829426
# Time (CPU seconds):             5.69
# Time (Wallclock seconds):       5.75
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       5.70   (Wallclock seconds):       5.75
#
# Tour:[0, 8, 4, 9, 1, 6, 3, 5, 7, 2]
# Cost of your tour: 9.01976429719804
# Trial # 19
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/josiahroa/workspace/cs-masters/5414-greedy-algorithms/karatsuba/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/37a5b1ac285f437bb702447d4896b2fe-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/37a5b1ac285f437bb702447d4896b2fe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 67 COLUMNS
# At line 496 RHS
# At line 559 BOUNDS
# At line 630 ENDATA
# Problem MODEL has 62 rows, 63 columns and 246 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 8.59919 - 0.00 seconds
# Cgl0003I 5 fixed, 0 tightened bounds, 42 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 37 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 41 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 38 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 28 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 61 rows, 58 columns (58 integer (51 of which binary)) and 434 elements
# Cbc0038I Initial state - 20 integers unsatisfied sum - 4.70657
# Cbc0038I Pass   1: suminf.    2.06967 (12) obj. 11.069 iterations 19
# Cbc0038I Pass   2: suminf.    2.25000 (9) obj. 11.3117 iterations 4
# Cbc0038I Pass   3: suminf.    2.84211 (11) obj. 16.6519 iterations 12
# Cbc0038I Pass   4: suminf.    1.88889 (9) obj. 13.401 iterations 17
# Cbc0038I Pass   5: suminf.    2.20000 (9) obj. 16.9855 iterations 9
# Cbc0038I Pass   6: suminf.    3.97006 (19) obj. 23.0003 iterations 22
# Cbc0038I Pass   7: suminf.    2.33929 (13) obj. 22.0106 iterations 17
# Cbc0038I Pass   8: suminf.    1.71429 (4) obj. 20.2033 iterations 20
# Cbc0038I Pass   9: suminf.    1.71429 (8) obj. 20.8327 iterations 7
# Cbc0038I Pass  10: suminf.    1.66667 (8) obj. 22.8161 iterations 12
# Cbc0038I Pass  11: suminf.    6.58809 (26) obj. 21.7516 iterations 19
# Cbc0038I Pass  12: suminf.    4.43393 (18) obj. 19.8745 iterations 18
# Cbc0038I Pass  13: suminf.    4.14286 (12) obj. 18.25 iterations 24
# Cbc0038I Pass  14: suminf.    2.80000 (14) obj. 16.122 iterations 10
# Cbc0038I Pass  15: suminf.    2.53333 (13) obj. 15.3449 iterations 13
# Cbc0038I Pass  16: suminf.    0.00000 (0) obj. 16.0618 iterations 7
# Cbc0038I Solution found of 16.0618
# Cbc0038I Cleaned solution of 16.0618
# Cbc0038I Rounding solution of 13.5869 is better than previous of 16.0618
#
# Cbc0038I Before mini branch and bound, 7 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 61 rows 58 columns, reduced to 61 rows 49 columns
# Cbc0038I Mini branch and bound improved solution from 13.5869 to 10.0414 (0.02 seconds)
# Cbc0038I Round again with cutoff of 9.90099
# Cbc0038I Reduced cost fixing fixed 21 variables on major pass 2
# Cbc0038I Pass  17: suminf.    5.12245 (19) obj. 9.67809 iterations 20
# Cbc0038I Pass  18: suminf.    5.65121 (18) obj. 9.7381 iterations 2
# Cbc0038I Pass  19: suminf.    5.65187 (20) obj. 9.90099 iterations 14
# Cbc0038I Pass  20: suminf.    4.57281 (16) obj. 9.90099 iterations 4
# Cbc0038I Pass  21: suminf.    4.75513 (19) obj. 9.90099 iterations 3
# Cbc0038I Pass  22: suminf.    4.93155 (22) obj. 9.90099 iterations 16
# Cbc0038I Pass  23: suminf.    3.82888 (20) obj. 9.90099 iterations 5
# Cbc0038I Pass  24: suminf.    3.33333 (10) obj. 8.97804 iterations 15
# Cbc0038I Pass  25: suminf.    4.00000 (11) obj. 9.42169 iterations 4
# Cbc0038I Pass  26: suminf.    3.72603 (19) obj. 9.90099 iterations 14
# Cbc0038I Pass  27: suminf.    3.80631 (20) obj. 9.90099 iterations 1
# Cbc0038I Pass  28: suminf.    5.54566 (18) obj. 9.35655 iterations 15
# Cbc0038I Pass  29: suminf.    5.65121 (18) obj. 9.7381 iterations 2
# Cbc0038I Pass  30: suminf.    5.65187 (20) obj. 9.90099 iterations 13
# Cbc0038I Pass  31: suminf.    4.57281 (16) obj. 9.90099 iterations 4
# Cbc0038I Pass  32: suminf.    4.75513 (19) obj. 9.90099 iterations 3
# Cbc0038I Pass  33: suminf.    4.93155 (22) obj. 9.90099 iterations 15
# Cbc0038I Pass  34: suminf.    3.82888 (20) obj. 9.90099 iterations 5
# Cbc0038I Pass  35: suminf.    3.33333 (10) obj. 8.97804 iterations 15
# Cbc0038I Pass  36: suminf.    4.00000 (11) obj. 9.42169 iterations 4
# Cbc0038I Pass  37: suminf.    3.72603 (19) obj. 9.90099 iterations 16
# Cbc0038I Pass  38: suminf.    3.80631 (20) obj. 9.90099 iterations 1
# Cbc0038I Pass  39: suminf.    5.54566 (18) obj. 9.35655 iterations 16
# Cbc0038I Pass  40: suminf.    5.65121 (18) obj. 9.7381 iterations 2
# Cbc0038I Pass  41: suminf.    6.18913 (21) obj. 9.90099 iterations 13
# Cbc0038I Pass  42: suminf.    6.13003 (23) obj. 9.90099 iterations 4
# Cbc0038I Pass  43: suminf.    5.88145 (19) obj. 9.90099 iterations 1
# Cbc0038I Pass  44: suminf.    4.88287 (16) obj. 9.90099 iterations 19
# Cbc0038I Pass  45: suminf.    5.65187 (20) obj. 9.90099 iterations 9
# Cbc0038I Pass  46: suminf.    4.57281 (16) obj. 9.90099 iterations 4
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 27 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 61 rows 58 columns, reduced to 53 rows 28 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 10.0414 - took 0.02 seconds
# Cbc0012I Integer solution of 10.041411 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0038I Full problem 61 rows 58 columns, reduced to 46 rows 16 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 1 added rows had average density of 17
# Cbc0013I At root node, 5 cuts changed objective from 8.6373329 to 10.041411 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 98 row cuts average 2.2 elements, 10 column cuts (10 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 5 row cuts average 18.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 67 row cuts average 12.1 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 1 row cuts average 14.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 10.0414107158807, took 28 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 24 variables fixed on reduced cost
# Cuts at root node changed objective from 8.63733 to 10.0414
# Probing was tried 3 times and created 108 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 2 times and created 67 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                10.04141072
# Enumerated nodes:               0
# Total iterations:               28
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Tour:[0, 6, 4, 7, 2, 5, 1, 3]
# Cost of your tour: 10.041410715880566
# Test Passed (10 points)
