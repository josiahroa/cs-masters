# %%
# !pip3 install pulp

# %%
from pulp import *

# Here is a useful function to implement the LHS upper bound that we need for the encoding
def lhsUpperBound(c_list, bounds):
    n = len(c_list)
    assert len(bounds) == n 
    upper_bnd = sum([(cj*lj) if cj < 0 else cj*uj for (cj, (lj, uj)) in zip(c_list, bounds) ])
    return upper_bnd

def solveForMaximumInequalitySatisfaction(n, m, c_matrix, d_values, bounds):
    # always check pre-conditions: saves so much time later
    assert len(c_matrix) == m
    assert all(len(c_list) == n for c_list in c_matrix)
    assert len(d_values) == m
    assert len(bounds) == n
    assert all (lj <= uj for (lj, uj) in bounds)
    
    
    prob = LpProblem("MaximizeInequalitiesSatisfied", LpMaximize)
    
    # Define decision variables
    x = []
    for i in range(n):
        x.append(LpVariable(f"x{i}", bounds[i][0],bounds[i][1]))
    
    satisfied = []
    for j in range(m):
        satisfied.append(LpVariable(f"satisfy{j}", 0, 1, cat="Binary"))
        
    prob += lpSum(satisfied)
    
    # Define Constraints
    for j in range(m):
        lhs = lpSum([c_matrix[j][i] * x[i] for i in range(n)])
        prob += (lhs <= d_values[j] + (1 - satisfied[j]) * 1e6)  
        prob += (lhs >= d_values[j] - 1e6 * satisfied[j]) 
    
    
    # Solve the problem
    prob.solve()
    
    # Extract results
    k = sum(1 for j in range(m) if satisfied[j].varValue > 0.5) 
    x_values = [x[i].varValue for i in range(n)] 
    
    return k, x_values

# %%
def testSolution(n, m, c_matrix, d_values, bounds, x_values, k_expected):
    # always check pre-conditions: saves so much time later
    assert len(c_matrix) == m
    assert all(len(c_list) == n for c_list in c_matrix)
    assert len(d_values) == m
    assert len(bounds) == n
    assert all (lj <= uj for (lj, uj) in bounds)
    assert len(x_values) == n
    assert 0 <= k_expected <= m
    # check solution within bounds
    for i in range(n):
        (lb, ub) = bounds[i]
        assert lb <= x_values[i] <= ub, f'x_{i} fails to be within its bounds {[lb, ub]}'
    # Check how many inequalities satisfied
    num_ineqs = 0
    
    for (c_list, d) in zip(c_matrix, d_values):
        if sum([cj * xj for (cj, xj) in zip(c_list,x_values )]) <= d+1E-3:
            num_ineqs = num_ineqs + 1
    assert num_ineqs == k_expected, f' Expected number of inequalities to be sat: {k_expected} your solution satisfies: {num_ineqs} inequalities '
    print('Test Passed')
    return 
        
        
        
        

# x_1 - x_2 & \leq -5 & \leftarrow I_1 \\ 
# x_1 + 2 x_2 & \leq 3 & \leftarrow I_2 \\ 
# x_1 & \geq 4  & \leftarrow I_3\\ 
# x_1 & \leq -2  & \leftarrow I_4\\ 
# x_2 & \geq 3  & \leftarrow I_5\\ 
# x_2 & \leq -1  & \leftarrow I_6\\ 

n = 2
m = 6
c_matrix = [
    [1, -1],
    [1, 2],
    [-1, 0],
    [1, 0],
    [-1, 0],
    [1, 0]
]

d_list = [
    -5, 3, -4, -2, -3, -1
]

bounds = [(-10, 10), (-10, 10)]

(k, x_values) = solveForMaximumInequalitySatisfaction(n, m, c_matrix, d_list, bounds)
testSolution(n, m, c_matrix, d_list, bounds, x_values, 4)
print('5 points')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/josiahroa/workspace/cs-masters/5414-greedy-algorithms/karatsuba/.venv/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/aa6e16e125064e85ab3fe07097628333-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/3g/sywttvsx0m34y00rmp2v39b00000gn/T/aa6e16e125064e85ab3fe07097628333-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 17 COLUMNS
# At line 64 RHS
# At line 77 BOUNDS
# At line 88 ENDATA
# Problem MODEL has 12 rows, 8 columns and 28 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 5.99999 - 0.00 seconds
# Cgl0004I processed model has 6 rows, 8 columns (6 integer (6 of which binary)) and 14 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 2 integers unsatisfied sum - 1.15e-05
# Cbc0038I Pass   1: suminf.    0.00001 (2) obj. -5.99999 iterations 0
# Cbc0038I Pass   2: suminf.    0.00001 (2) obj. -5.99999 iterations 0
# Cbc0038I Pass   3: suminf.    0.00001 (3) obj. -4.99999 iterations 2
# Cbc0038I Pass   4: suminf.    0.00001 (3) obj. -4.99999 iterations 0
# Cbc0038I Pass   5: suminf.    0.00001 (3) obj. -4.99999 iterations 0
# Cbc0038I Pass   6: suminf.    0.00001 (1) obj. -3.99999 iterations 4
# Cbc0038I Pass   7: suminf.    0.00001 (1) obj. -3.99999 iterations 0
# Cbc0038I Pass   8: suminf.    0.00001 (1) obj. -3.99999 iterations 0
# Cbc0038I Pass   9: suminf.    0.00001 (1) obj. -3.99999 iterations 0
# Cbc0038I Pass  10: suminf.    0.00001 (2) obj. -3.99999 iterations 4
# Cbc0038I Pass  11: suminf.    0.00001 (2) obj. -3.99999 iterations 0
# Cbc0038I Pass  12: suminf.    0.00001 (2) obj. -3.99999 iterations 0
# Cbc0038I Pass  13: suminf.    0.00001 (1) obj. -4 iterations 4
# Cbc0038I Pass  14: suminf.    0.00001 (1) obj. -4 iterations 0
# Cbc0038I Pass  15: suminf.    0.00001 (1) obj. -4 iterations 0
# Cbc0038I Pass  16: suminf.    0.00001 (1) obj. -4 iterations 0
# Cbc0038I Pass  17: suminf.    0.00000 (0) obj. -2 iterations 2
# Cbc0038I Solution found of -2
# Cbc0038I Relaxing continuous gives -2
# Cbc0038I Rounding solution of -4 is better than previous of -2
#
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 6 rows 8 columns, reduced to 6 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -5.09991
# Cbc0038I Reduced cost fixing fixed 1 variables on major pass 2
# Cbc0038I Pass  18: suminf.    0.00001 (2) obj. -5.99999 iterations 0
# Cbc0038I Pass  19: suminf.    0.00001 (2) obj. -5.99999 iterations 0
# Cbc0038I Pass  20: suminf.    0.09993 (3) obj. -5.09991 iterations 2
# Cbc0038I Pass  21: suminf.    0.09993 (4) obj. -5.09991 iterations 1
# Cbc0038I Pass  22: suminf.    0.09993 (4) obj. -5.09991 iterations 0
# Cbc0038I Pass  23: suminf.    0.09993 (4) obj. -5.09991 iterations 0
# Cbc0038I Pass  24: suminf.    0.09993 (4) obj. -5.09991 iterations 0
# Cbc0038I Pass  25: suminf.    0.09993 (4) obj. -5.09991 iterations 2
# Cbc0038I Pass  26: suminf.    0.09993 (4) obj. -5.09991 iterations 0
# Cbc0038I Pass  27: suminf.    0.09995 (4) obj. -5.09991 iterations 1
# Cbc0038I Pass  28: suminf.    0.09992 (2) obj. -5.09991 iterations 3
# Cbc0038I Pass  29: suminf.    0.09992 (2) obj. -5.09991 iterations 2
# Cbc0038I Pass  30: suminf.    0.09992 (2) obj. -5.09991 iterations 0
# Cbc0038I Pass  31: suminf.    0.00001 (3) obj. -5.99999 iterations 4
# Cbc0038I Pass  32: suminf.    0.00001 (3) obj. -5.99999 iterations 0
# Cbc0038I Pass  33: suminf.    0.09992 (2) obj. -5.09991 iterations 2
# Cbc0038I Pass  34: suminf.    0.00001 (2) obj. -5.99999 iterations 1
# Cbc0038I Pass  35: suminf.    0.09993 (3) obj. -5.09991 iterations 4
# Cbc0038I Pass  36: suminf.    0.09993 (3) obj. -5.09991 iterations 0
# Cbc0038I Pass  37: suminf.    0.09993 (3) obj. -5.09991 iterations 0
# Cbc0038I Pass  38: suminf.    0.09993 (3) obj. -5.09991 iterations 0
# Cbc0038I Pass  39: suminf.    0.09993 (3) obj. -5.09991 iterations 0
# Cbc0038I Pass  40: suminf.    0.09993 (3) obj. -5.09991 iterations 0
# Cbc0038I Pass  41: suminf.    0.09993 (3) obj. -5.09991 iterations 0
# Cbc0038I Pass  42: suminf.    0.09993 (3) obj. -5.09991 iterations 2
# Cbc0038I Pass  43: suminf.    0.09992 (2) obj. -5.09991 iterations 3
# Cbc0038I Pass  44: suminf.    0.09992 (2) obj. -5.09991 iterations 2
# Cbc0038I Pass  45: suminf.    0.09992 (2) obj. -5.09991 iterations 0
# Cbc0038I Pass  46: suminf.    0.00001 (3) obj. -5.99999 iterations 4
# Cbc0038I Pass  47: suminf.    0.00001 (3) obj. -5.99999 iterations 0
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 6 rows 8 columns, reduced to 5 rows 7 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -5.27992
# Cbc0038I Reduced cost fixing fixed 1 variables on major pass 3
# Cbc0038I Pass  47: suminf.    0.00001 (2) obj. -5.99999 iterations 0
# Cbc0038I Pass  48: suminf.    0.00001 (2) obj. -5.99999 iterations 0
# Cbc0038I Pass  49: suminf.    0.00001 (2) obj. -5.99999 iterations 0
# Cbc0038I Pass  50: suminf.    0.27994 (4) obj. -5.27992 iterations 4
# Cbc0038I Pass  51: suminf.    0.27994 (4) obj. -5.27992 iterations 0
# Cbc0038I Pass  52: suminf.    0.27994 (4) obj. -5.27992 iterations 0
# Cbc0038I Pass  53: suminf.    0.27994 (4) obj. -5.27992 iterations 0
# Cbc0038I Pass  54: suminf.    0.27994 (4) obj. -5.27992 iterations 0
# Cbc0038I Pass  55: suminf.    0.27995 (4) obj. -5.27992 iterations 1
# Cbc0038I Pass  56: suminf.    0.27994 (3) obj. -5.27992 iterations 4
# Cbc0038I Pass  57: suminf.    0.27995 (3) obj. -5.27992 iterations 3
# Cbc0038I Pass  58: suminf.    0.27995 (3) obj. -5.27992 iterations 0
# Cbc0038I Pass  59: suminf.    0.27995 (3) obj. -5.27992 iterations 0
# Cbc0038I Pass  60: suminf.    0.27994 (3) obj. -5.27992 iterations 2
# Cbc0038I Pass  61: suminf.    0.27994 (2) obj. -5.27992 iterations 2
# Cbc0038I Pass  62: suminf.    0.00001 (2) obj. -5.99999 iterations 2
# Cbc0038I Pass  63: suminf.    0.00001 (2) obj. -5.99999 iterations 0
# Cbc0038I Pass  64: suminf.    0.27994 (4) obj. -5.27992 iterations 4
# Cbc0038I Pass  65: suminf.    0.27994 (4) obj. -5.27992 iterations 0
# Cbc0038I Pass  66: suminf.    0.27994 (4) obj. -5.27992 iterations 0
# Cbc0038I Pass  67: suminf.    0.27994 (4) obj. -5.27992 iterations 0
# Cbc0038I Pass  68: suminf.    0.27997 (4) obj. -5.27992 iterations 3
# Cbc0038I Pass  69: suminf.    0.00001 (2) obj. -5.99999 iterations 3
# Cbc0038I Pass  70: suminf.    0.27995 (4) obj. -5.27992 iterations 2
# Cbc0038I Pass  71: suminf.    0.27995 (4) obj. -5.27992 iterations 0
# Cbc0038I Pass  72: suminf.    0.27995 (3) obj. -5.27992 iterations 1
# Cbc0038I Pass  73: suminf.    0.27995 (4) obj. -5.27992 iterations 1
# Cbc0038I Pass  74: suminf.    0.27995 (4) obj. -5.27992 iterations 0
# Cbc0038I Pass  75: suminf.    0.27994 (2) obj. -5.27992 iterations 2
# Cbc0038I Pass  76: suminf.    0.27995 (3) obj. -5.27992 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 6 rows 8 columns, reduced to 5 rows 7 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -4 - took 0.00 seconds
# Cbc0012I Integer solution of -4 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 6 rows 8 columns, reduced to 4 rows 4 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from -5.9999885 to -5.9999885 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -4, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -5.99999 to -5.99999
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.02
#
# Test Passed
# 5 points
